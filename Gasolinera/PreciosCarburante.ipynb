# %% [markdown]
# <h1 style = "text-align:center; front-size: 36px">Programación Concurrente y Distribuida </h1>
# <a href="https://github.com/RubenMartinezGormaz">
#     <img src="https://avatars.githubusercontent.com/u/90790008?v=4" title = "Rubén Martínez 22037408" alt="Rubén Martínez Gormaz 22037408" width="100" height="100" style="float:left;vertical-align:centre">
#     <img src="https://media-exp1.licdn.com/dms/image/C4D0BAQEu_Aa76fcmPw/company-logo_200_200/0/1630998679429?e=2159024400&v=beta&t=2feC9GG7RWCWizTqsK5HzDWB1TL2DOQuAVwnMf6FFvk" title = "M21" alt="UE" width="105" height="105" style="float:right;vertical-align:centre">

# %% [markdown]
# ## CARGAR DATOS

# %% [markdown]
# ### 1. Loading excel files, está en local

# %% [markdown]
# ### 2. Loadin csv files, está en la nube
# https://datos.madrid.es/egob/catalogo/300107-0-agenda-actividades-eventos.csv

# %%
import requests as rq, pandas as pd

# %%
url_= 'https://datos.madrid.es/egob/catalogo/300107-0-agenda-actividades-eventos.csv'

# %%
gasolinas = pd.read_excel("preciosEESS_es.xls")

# %%
gasolinas
# Out:
#              Fecha:                                   20/10/2021 17:00  \
# 0      Descripción:  Archivo de todos los productos en todas las es...
# 1           Siglas:  Margen - D: Derecho, I: Izquierdo, N: No aplic...
# 2         Provincia                                          Municipio
# 3          ALBACETE                                          ABENGIBRE
# 4          ALBACETE                                             ALATOZ
# ...             ...                                                ...
# 11420      ZARAGOZA                                           ZARAGOZA
# 11421      ZARAGOZA                                           ZARAGOZA
# 11422      ZARAGOZA                                              ZUERA
# 11423      ZARAGOZA                                              ZUERA
# 11424      ZARAGOZA                                              ZUERA
#
#             Unnamed: 2     Unnamed: 3                      Unnamed: 4  \
# ...

# %%
res_ =rq.api.get(url_)

# %%
res_.headers

# %%
res_.text

# %%
raw_data = open("parcal_pregunta.csv", 'wb')

# %%
with open("moreno_delegado.csv", 'wb') as r_data:
    r_data.write(res_.content)

# %% [markdown]
# ## Recomendable usar WITH, context manager

# %%
raw_data.write(res_.content)

# %%
raw_data.close()

# %%
ls parcal_pregunta.csv

# %%
less parcal_pregunta.csv

# %%
ls moreno_delegado.csv

# %%
final_file = pd.read_csv("moreno_delegado.csv", sep= ';', encoding= "Latin 1")

# %%
final_file
# Out:
#       ID-EVENTO                                             TITULO  \
# 0      11457499  1ª Edición Festival Internacional de Luz de Ma...
# 1      11461367                35º Certamen coreográfico de Madrid
# 2      11488627                               3. Concierto Clásico
# 3      11488635                             4. Concierto Romántico
# 4      11480760              5 Pintores por Amor al Arte. Pintura.
# ..          ...                                                ...
# 995    11418052                                 VI Flamenco Madrid
# 996    11484367                              VI Salón del Realismo
# 997    11407933                           VI Torneo de Dramaturgia
# 998    11498259                          Viaje a la Grecia clásica
# 999    11472779                                    Viaje al futuro
#
#                                         PRECIO  GRATUITO  LARGA-DURACION  \
# 0                                          NaN         1             1.0
# ...
